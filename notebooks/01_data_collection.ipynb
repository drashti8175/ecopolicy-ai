# %% [markdown]
# # 01_data_collection.ipynb
#
# This notebook performs Week 2 data collection steps: create folders, save `requirements.txt`, load Kaggle bootstrap data, fetch CPCB live snapshots, query OpenAQ, and download Open-Meteo historical weather for Pune. Replace API keys/placeholders before running CPCB/OpenAQ cells.

# %%
# Cell 2: Create folder structure and write requirements.txt
import os
base = os.path.join('..','')  # notebook is inside notebooks/; adjust if running from repo root
paths = [
    'data/raw/cpcb',
    'data/raw/weather',
    'data/processed',
    'notebooks',
# Out:
#   Cell In[1], line 8
#     'notebooks',
#                 ^
# SyntaxError: incomplete input
